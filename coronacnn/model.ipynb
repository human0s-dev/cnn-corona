# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_path = "/home/manas/Desktop/cnn/test/IM-0001-0001.jpeg"

img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

plt.imshow(img, cmap='gray')
plt.axis('off')
plt.show()

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Directory containing the dataset
train_dir = 'chest_xray/train/'
test_dir = 'chest_xray/test/'

img_path = "/home/manas/Desktop/cnn/test/IM-0001-0001.jpeg"
# Image size expected by the model
IMG_SIZE = 150

def preprocess_image(img_path):
    img = cv2.imread(img_path[0])
    # Load the image in grayscale
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    # Resize to the required dimensions
    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    # Normalize the image
    img = img / 255.0
    return img

img = preprocess_image(img_path)

plt.imshow(img)
plt.title('Patient 1')
plt.axis('off')
plt.show()
# Out:
# [ WARN:0@562.061] global loadsave.cpp:275 findDecoder imread_('/home/manas/Desktop/cnn/test/1-s2.0-S0140673620303706-fx1_lrg.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[10], line 25
#      22     img = img / 255.0
#      23     return img
# ---> 25 img = preprocess_image(img_path)
#      27 plt.imshow(img)
#      28 plt.title('Patient 1')
#
# Cell In[10], line 20, in preprocess_image(img_path)
#      18 img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#      19 # Resize to the required dimensions
# ---> 20 img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
#      21 # Normalize the image
#      22 img = img / 255.0
#
# error: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
